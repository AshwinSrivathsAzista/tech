# %%
a = "asdfasdfasdfadsf"

# %%
a[:-1]
# Out:
# 'asdfasdfasdfads'

# %%
a = ()
type(a)
# Out:
# tuple

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import sklearn

# %%
a = np.arange(0.0001,100, 0.01)


plt.plot(a, np.log(a))
