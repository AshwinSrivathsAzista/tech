# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# line plot
x = np.linspace(-1000, 1000, 1000)

y = 1/(1 + np.exp(-x))   
plt.plot(x, y)
plt.title("sigmoid Wave")
# Out:
# C:\Users\ashwi\AppData\Local\Temp\ipykernel_11748\3041738961.py:4: RuntimeWarning: overflow encountered in exp
#   y = 1/(1 + np.exp(-x))
# Text(0.5, 1.0, 'sigmoid Wave')
