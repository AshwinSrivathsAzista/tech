# %%
# import 'pandas'
import pandas as pd

# import 'numpy'
import numpy as np

# import subpackage of matplotlib
import matplotlib.pyplot as plt

# import 'seaborn'
import seaborn as sns

# to suppress warnings
from warnings import filterwarnings
filterwarnings('ignore')

# import statsmodels
import statsmodels.api as sm

# import 'stats' package from scipy library
import scipy.stats as stats

# import statistics to perform statistical computations
import statistics

# to test the normality
from scipy.stats import shapiro

# import a library to perform Z-test
from statsmodels.stats import weightstats as stests

# import statsmodels
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm
from scipy.stats import zscore
# import the functions to perform Chi-square tests
from scipy.stats import chi2_contingency
from scipy.stats import chi2
from scipy.stats import chisquare

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy.linalg as la
from numpy.linalg import inv ,det
from numpy import linalg as LA

from sympy import Symbol, Derivative
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from PIL import Image, ImageFilter, ImageOps

# %% [markdown]
# Section A  (Pen and paper answer)
#
# PArt 1 (2 marks each)
#
# Q1:
#
# a. State the measures of dispersion and explain about any of them.
#
# b. List four different types of sampling methods
#
# c. What does ANOVA stand for? State its purpose . Why is it preferred to multiple paired t-tests ?
#
# d. Consider the following two samples:
# Sample 1: 10, 9, 8, 7, 8, 6, 10, 6
# Sample 2: 10, 6, 10, 6, 8, 10, 8, 6
#
# e. Compare the samples in terms of mean, standard deviation
#
#
# What are the various measures a box plot provides

# %% [markdown]
# PART 2: (5 mark each)
#
#
# f. Define a scalar and a vector. Give one example of each. Calculate the angle between two given vectors. The two vectors are,     a =3i + 4j  and  b = 6i  + 8j
#
# g. What is the effect of learning rate in Gradient descent algorithm? Explain briefly.

# %% [markdown]
# # Section C (40 marks)

# %% [markdown]
# **The data definition is as follows:** <br><br>
# **Car_Name:** name of the car <br>
#
# **YearThis:** year in which the car was bought <br>
#
# **Present_Price:** current ex-showroom price of the car (in lakhs)<br>
#
# **Kms_Driven:** distance completed by the car in km <br>
#
# **Fuel_Type:** fuel type of the car <br>
#
# **Seller_Type:** defines whether the seller is a dealer or an individual<br>
#
# **Transmission:** defines whether the car is manual or automatic <br>
#
# **Owner:** defines the number of owners the car has previously had <br>
#
# **Selling_Price:** price the owner wants to sell the car at (in lakhs) (response variable)

# %%
# read the data
df_car = pd.read_csv("car_data.csv")

# %%
df_car
# Out:
#     Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0       ritz  2014           3.35           5.59       27000    Petrol
# 1        sx4  2013           4.75           9.54       43000    Diesel
# 2       ciaz  2017           7.25           9.85        6900    Petrol
# 3    wagon r  2011           2.85           4.15        5200    Petrol
# 4      swift  2014           4.60           6.87       42450    Diesel
# ..       ...   ...            ...            ...         ...       ...
# 296     city  2016           9.50          11.60       33988    Diesel
# 297     brio  2015           4.00           5.90       60000    Petrol
# 298     city  2009           3.35          11.00       87934    Petrol
# 299     city  2017          11.50          12.50        9000    Diesel
# 300     brio  2016           5.30           5.90        5464    Petrol
#
#     Seller_Type Transmission  Owner
# 0        Dealer       Manual      0
# 1        Dealer       Manual      0
# ...

# %% [markdown]
# ### i) What are the summary statistics (mean, median, min, max) for the Selling_Price and Present_Price of cars? (2 marks)

# %% [markdown]
# ### ii) Calculate the 95% confidence intervals for the mean Selling_Price of cars across different Fuel_Type categories. Interpret the intervals and discuss any overlaps. (5 marks )

# %% [markdown]
# ### iii) Identify and analyze outliers in the Selling_Price data using the IQR (Interquartile Range) method. How many outliers are there, and what impact might they have on the overall analysis? (5 marks)

# %% [raw]
# The selling price for cars and bikes generally decreases with age. For instance, newer models tend to have higher selling prices compared to older ones.
#
# High-end models like the Fortuner and Innova maintain higher resale values compared to budget models like the Alto and Wagon R.

# %% [markdown]
# ###  iv) Compute the Z-scores for Present_Price to standardize the data. Identify any values that are considered outliers (Z-score > 3 or < -3). (5 marks)

# %% [markdown]
# ###  v) Is there a correlation between Selling_Price and Kms_Driven? If so, how strong is it?  (3 marks)

# %% [raw]
# A correlation coefficient of 0.02 suggests a very weak positive correlation between Selling_Price and Kms_Driven in your dataset. This indicates that there is a slight tendency for Selling_Price to increase with Kms_Driven, but the relationship is not strong.

# %% [markdown]
# 2. Section c (40 marks)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy.linalg as la
from numpy.linalg import inv ,det
from numpy import linalg as LA

from sympy import Symbol, Derivative
from sklearn.datasets import load_breast_cancer
from sklearn.preprocessing import StandardScaler
from PIL import Image, ImageFilter, ImageOps

# %% [markdown]
# #### (a) Consider the following vectors and answer the below 2 questions:
#
# Given the vectors:
#
# $
# P = \begin{bmatrix} 2 \\ -1 \\ 3 \end{bmatrix}, \quad
# Q = \begin{bmatrix} 4 \\ 0 \\ 5 \end{bmatrix}, \quad
# R = \begin{bmatrix} k \\ 2 \\ -2 \end{bmatrix}
# $
#
# where $( k $) is an unknown scalar.
#
# (i) Form a matrix $( N $) with these vectors as columns. For what value of $( k $), if any, do the vectors become linearly dependent? Also, find the rank of the matrix for this value of $( k $). (4 marks )
#
# (ii) Check if the matrix $( N $) is an orthogonal matrix when $( k = 1 $). (3 marks)

# %% [markdown]
# #### (b) Find the Eigenvalues of a Matrix and its Powers
#
# Consider the matrix:
#
# $
# A = \begin{bmatrix} 5 & 2 \\ 1 & 4 \end{bmatrix}
# $
#
#  Step 1: Find the Eigenvalues of $( A $)
#
#  Step 2: Find the Eigenvalues of $( A^2 $)
#
#  Step 3: Find the Eigenvalues of $( A^{-1} $)
#
#  Step 4: Interpret Results
#
# **Marks: 7**

# %% [markdown]
# ## (b) Find the scalar and vector projections of the vector
#
# Given:
# $
# \mathbf{u} = 8\mathbf{i} + 6\mathbf{j}, \quad \mathbf{v} = \mathbf{i} - 7\mathbf{j}
# $
#
# ### **Tasks:**
# (i) **Find the scalar projection** of $( \mathbf{u} $) on $( \mathbf{v} $). *(3 marks)*
# - Formula:
#   $[
#   \text{Scalar Projection} = \frac{\mathbf{u} \cdot \mathbf{v}}{\|\mathbf{v}\|}
#   $]
#
# (ii) **Find the vector projection** of $( \mathbf{u} $) on $( \mathbf{v} $). *(3 marks)*
# - Formula:
#   $[
#   \text{Vector Projection} = \left( \frac{\mathbf{u} \cdot \mathbf{v}}{\|\mathbf{v}\|^2} \right) \mathbf{v}
#   $]
#
# ---
# **Marks: 6**

# %% [markdown]
# (d) Singular Value Decomposition (SVD) of a Matrix
#
# Consider the matrix:
#
# $
# B = \begin{bmatrix} 2 & 4 & 6 \\ 1 & 3 & 5 \end{bmatrix}
# $
#
# **6 marks**

# %%
# Define the matrix A
# Calculate the singular value decomposition of A
# Extract Components
# Output the results

# %% [markdown]
# #### (e) Convert the following matrix to an orthogonal matrix using the Gram-Schmidt Process
#
# Consider the matrix:
#
# $
# C = \begin{bmatrix}
# 2 & 1 & 3 \\
# 1 & 2 & 1 \\
# 4 & 0 & 2
# \end{bmatrix}
# $
#
# Step 1: Apply the Gram-Schmidt Process
#
# Step 2: Verify Orthogonality
#
#
# ---
# **7 Marks**

# %% [markdown]
# (f) Find the Critical Points of the Function
#
# Given the function:
#
# $
# f(x) = x^3 - 6x^2 + 9x + 5
# $
#
# ### **Tasks:**
# (i) **Find the critical points**  *(4 marks)*
#
# (ii) **Determine the nature of each critical point**  *(3 marks)*
#
# ---
# **Marks: 7**

# %%
# follow the following steps

# Define the symbol
# Define the function
# Compute the derivative of the function
# Find the critical points by solving f'(x) = 0
# Evaluate the function at the critical points
# Display the results

# %% [markdown]
# ## 3. Section C (40 marks)

# %% [markdown]
# (a) Consider the image given in the folder and perform the following operations:
#
#    1.  Apply Gaussian blur filter
#    2.  Apply Sharpening Filter
#    3.  Convert the Image to Negative
#    4.  Resize the Image to the half size
#    5.  Rotate the image by 45 degrees
#    6.  Translate the image (Move 100 pixels right, 50 pixels down)
#
# 10 marks

# %%
# Step 1: Load the image
image_path = "/home/MF feb 2025/Question/cat.jpeg"
image = Image.open(image_path)

# Step 2: Display the original image
#plt.figure(figsize=(10, 10))
#plt.subplot(3, 3, 1)
#plt.imshow(image)
#plt.title("Original Image")
#plt.axis("off")


## Image Processing Task


#Step 3: Apply Gaussian blur filter

#Step 4: Apply Sharpening Filter

#Step 5: Convert the Image to Negative

#Step 6: Resize the Image to the half size

#Step 7: Rotate the image by 45 degrees

#Step 8: Translate the image
 #    Move 100 pixels right, 50 pixels down

# %% [markdown]
# ### (b)Problem Statement:
#
# Given a dataset, perform Principal Component Analysis (PCA) to capture 90% variance in the data. You are required to complete the following steps:

# %%
# Step 1: Load the breast cancer dataset using the following code
BC_data = load_breast_cancer()
X = BC_data.data
y = BC_data.target
feature_names = BC_data.feature_names

# Step 2: Standardize the Data

# Step 3: Compute the Covariance Matrix

# Step 4: Compute the Eigenvectors and Eigenvalues

# Step 5: Select Principal Components

# Sort eigenvalues and eigenvectors in descending order

# Select the top k eigenvectors based on the explained variance ratio

# Step 6: Project Data onto Principal Components


# Display the explained variance ratio and cumulative explained variance ratio

# %% [markdown]
#
#
# #### **(c) Problem Statement:**
# Given the dataset below, fit a **linear regression line** $( y = ax + b $) using **gradient descent**.
#
# | ( X )    | ( Y )    |
# |----------|----------|
# | 0        | 1        |
# | 0.3      | 1.2      |
# | 0.7      | 0.8      |
# | 1        | 1.5      |
#
#
# **Marks: 15**
#
#
# ### Instructions
# In this notebook, you will work on implementing gradient descent for a simple linear regression problem. You will be provided with the data and hints for each question. Complete each step and run the notebook to see how the parameters update and the final fit of the model.

# %% [markdown]
# #### (i) Initializing Parameters and Defining the Loss Function  (3 marks )
# Write a Python function to:
# 1. Initialize the parameters $b$ (intercept) and $a$ (slope) to 0.
# 2. Define a **Mean Squared Error (MSE)** loss function for a given dataset.
#
# ##### Hint:
# Use the formula for MSE:
# $
# \text{MSE} = \frac{1}{n} \sum_{i=1}^{n} (y_i - (b + a x_i))^2
# $

# %%
# Function to initialize parameters and compute MSE
def initialize_parameters():
    #write your code here ( values of a and b)
    return b, a

def compute_mse(b, a, x, y):
    n = len(y)
    mse = #write your code here(mse formula)
    return mse

# Test the functions
b, a = initialize_parameters()
mse = compute_mse(b, a, x, y)
print(f"Initial MSE: {mse:.2f}")

# %% [markdown]
# #### (ii) Compute the Gradients  (3 marks )
# Write a Python function to compute the partial derivatives of the loss function with respect to $b$ and $a$.
#
# ##### Hint:
#
# The gradients are calculated as follows:
#
# $
#  \frac{\partial \text{MSE}}{\partial b} = \frac{-2}{n} \sum_{i=1}^{n} (y_i - (b + a x_i))
# $
#
# $
#  \frac{\partial \text{MSE}}{\partial a} = \frac{-2}{n} \sum_{i=1}^{n} (x_i \cdot (y_i - (b + a x_i)))
# $

# %%
# Function to compute gradients
def compute_gradients(b, a, x, y):
    n = len(y)
    error = y - (b+ a * x)
    d_b = # compute partial derivative on MSE wrt b
    d_a = # compute partial derivative on MSE wrt a
    return d_b, d_a

#Test the function
d_b, d_a = compute_gradients(b, a, x, y)
print(f"Gradients: d_theta_0 = {d_b:.2f}, d_theta_1 = {d_a:.2f}")

# %% [markdown]
# #### (iii) Implement Gradient Descent (One Iteration)   (4 marks)
# Implement a single iteration of gradient descent using the gradients calculated in Question 2. Use a learning rate \( \alpha = 0.01 \).
#
# ##### Hint:
# Update the parameters using the following formulas:
#
# $
# b = b - \alpha \cdot \frac{\partial \text{MSE}}{\partial b}
# $
#
# $
# a = a - \alpha \cdot \frac{\partial \text{MSE}}{\partial a}
# $

# %%
# Function to perform one iteration of gradient descent
def gradient_descent(b, a, x, y, learning_rate=0.01):
   # write the required code to perform above operation( write formula for b and a)
    return b, a

# Perform one step of gradient descent

b, a = gradient_descent(b, a, x, y)

# %% [markdown]
# #### (iv) Run Gradient Descent for 100 Iterations   (3 marks )
# Modify your gradient descent function to run for **100 iterations** and return the optimized parameters $a$ and $b$.
#
# ##### Hint:
# Use a loop to update the parameters iteratively and observe how the MSE decreases over iterations.

# %%
# Function to run gradient descent for multiple iterations
def run_gradient_descent(x, y, iterations=100, learning_rate=0.01):
    a,b = initialize_parameters() # Initialize parameters a (slope) and b (intercept)
    for i in range(iterations):
        a,b = gradient_descent(b, a, x, y, learning_rate)
        if i % 10 == 0:
            mse = compute_mse(b, a, x, y)
            print(f"Iteration {i}: MSE = {mse:.2f}")
    return b, a

# %%
# Run gradient descent
a_opt, b_opt = run_gradient_descent(x, y)
print(f"Final Parameters: b = {b:.2f}, a = {a:.2f}")

# %% [markdown]
# #### (v) Plot the data and the regression line  (2 marks)

# %%
plt.scatter(x, y, color='blue', label='Data points')
y_pred = #Write your code here
plt.plot(#, #, color='red', label='Regression line')# fill the #
plt.xlabel('x')
plt.ylabel('y')
plt.title('Linear Regression Fit')
plt.legend()
plt.show()
