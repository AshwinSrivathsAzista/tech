# %% [markdown]
# ### MODEL ESA AMES 3

# %%
# import 'pandas'
import pandas as pd

# import 'numpy'
import numpy as np

# import subpackage of matplotlib
import matplotlib.pyplot as plt

# import 'seaborn'
import seaborn as sns

# to suppress warnings
from warnings import filterwarnings
filterwarnings('ignore')

# import statsmodels
import statsmodels.api as sm

# import 'stats' package from scipy library
import scipy.stats as stats

# import statistics to perform statistical computations
import statistics

# to test the normality
from scipy.stats import shapiro

# import a library to perform Z-test
from statsmodels.stats import weightstats as stests

# import statsmodels
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# import the functions to perform Chi-square tests
from scipy.stats import chi2_contingency
from scipy.stats import chi2
from scipy.stats import chisquare

# %% [markdown]
# # Section A ( 20 marks )
#
#
# Q1. (2 marks each)
#
# a. The sample space of a random experiment is {a, b, c, d, e} with probabilities 0.1, 0.1, 0.2, 0.4, and 0.2, respectively. Let A denote the event {a, b, c}, and let B denote the event {c, d, e}. Determine the following : P(A), P(B)
#
# b. Define Central Limit Theorem.
#
# c. Under what conditions would you prefer using one sample t test.
#
# d. Explain briefly about Chi square goodness of fit test.
#
# e. Define Bayes theorem and provide with an example where Bayes theorem can be applied.

# %% [markdown]
# f. Explain the following concepts with suitable examples:
#
# (a) Linear Independence of Vectors
#
#  (b) Invertible (Non-singular) Matrix
#
#  (5 marks )
#
#
# g. A point P(2,3) is transformed using the matrix
# T=[0 -1],[1 0]
#
# (a) Find the image of the point P under this transformation.
#
#  (b) Identify the type of transformation represented by matrix T. Explain your reasoning.
#
#
#  (5 marks )

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import numpy.linalg as la
from numpy.linalg import inv ,det
from numpy import linalg as LA

from sympy import Symbol, Derivative
from sklearn.datasets import load_diabetes
from sklearn.preprocessing import StandardScaler
from PIL import Image, ImageFilter, ImageOps

# %% [markdown]
# #### (a) Consider the following vectors and answer the questions below:
#
# Given the vectors:
#
# $
# A = \begin{bmatrix} 1 \\ 2 \\ -1 \end{bmatrix}, \quad
# B = \begin{bmatrix} 3 \\ -1 \\ 4 \end{bmatrix}, \quad
# C = \begin{bmatrix} 2 \\ m \\ 5 \end{bmatrix}
# $
#
# where \( m \) is an unknown scalar.
#
#
#
# (i) Form a matrix \( M \) with these vectors as columns. For what value of \( m \), if any, do the vectors become linearly dependent?  Also, find the rank of the matrix for this value of \( m \). (4 marks)
#
# (ii) Check if the matrix \( M \) is an orthogonal matrix when \( m = 1 \).  (3 marks)

# %% [markdown]
# #### (b) Find the Eigenvalues of a Matrix and its Powers
#
# Consider the matrix:
#
# $
# A = \begin{bmatrix} 5 & 2 & 1 \\ 3 & 1 & 4 \\ 1 & 6 & 9\end{bmatrix}
# $
#
#  Step 1: Find the Eigenvalues of $( A $)
#
#  Step 2: Find the Eigenvalues of $( A^2 $)
#
#  Step 3: Find the Eigenvalues of $( A^{-1} $)
#
#  Step 4: Interpret Results
#
# **Marks: 7**

# %% [markdown]
# #### Interpretation of Eigenvalues:
#
# - The eigenvalues of $( A^2 $) are the **squares** of the eigenvalues of $( A $).
#
# - The eigenvalues of $( A^{-1}$) are the **reciprocals** of the eigenvalues of $(A $).

# %% [markdown]
# #### (b) Find the scalar and vector projections of the vector
#
# Given:
# $
# \mathbf{u} = 8\mathbf{i} + 6\mathbf{j}, \quad \mathbf{v} = \mathbf{i} - 7\mathbf{j}
# $
#
#
# (i) Find the scalar projection of $( \mathbf{u} $) on $( \mathbf{v} $). *(3 marks)*
#
# (ii) Find the vector projection of $( \mathbf{u} $) on $( \mathbf{v} $). *(3 marks)*
#
#
# ---
# **Marks: 6**

# %% [markdown]
# #### (d)  Consider the matrix:
#
# $
# D = \begin{bmatrix} 3 & 1 & 1 \\ -1 & 3 & 1 \end{bmatrix}
# $
#
# 1. Perform the Singular Value Decomposition (SVD) of matrix \( D \), i.e., find matrices $( U $), $( \Sigma $), and $( V^T $) such that
# $[
# D = U \Sigma V^T
# $]
# (3 marks)
#
# 2. Reconstruct matrix $( D $) using only the first singular value and its corresponding vectors from $( U $), $( \Sigma $), and $( V^T $).
# Print the approximate matrix and compare it with the original matrix $( D $). (3 marks)

# %%
# Step 1: perform Full SVD
# Step 2: Reconstruct D using all components
# Step 3: Rank-1 approximation using only the first singular value
# Step 4: Compare with original
# Optional: Error of approximation

# %% [markdown]
# #### (e) Orthonormalization Using Gram-Schmidt Process
#
# Given the matrix:
#
# $
# M = \begin{bmatrix}
# 1 & 2 & 1 \\
# 2 & 0 & 2 \\
# 1 & 1 & 3
# \end{bmatrix}
# $
#
# 1. Use the Gram-Schmidt Process to convert the columns of matrix $( M $) into an orthonormal set of vectors. (5 marks)
#
# 2. Form a matrix $( Q $) using these orthonormal vectors as columns and verify that $( Q^T Q = I $), confirming orthonormality. (2 marks)
#
# ---
# **7 Marks**

# %% [markdown]
# #### (f) Analyze the Critical Points of the Function
#
# Given the function:
#
# $
# f(x) = x^3 - 3x^2 + 2
# $
#
# (i) **Find all critical points** by computing and solving $( f'(x) = 0 $).
# (4 marks)
#
# (ii) **Identify which critical point gives the minimum and which gives the maximum value of the function** by evaluating $( f(x) $) at those points.
# (3 marks)
#
# ---
# **Total Marks: 7**

# %%
# follow the following steps

# Define the symbol
# Define the function
# Compute the derivative of the function
# Find the critical points by solving f'(x) = 0
# Evaluate the function at the critical points
# Display the results

# %% [markdown]
# ### 4a) Consider the purchases.csv file and answer the following questions

# %%
df_prod = pd.read_csv('purchase.csv')
# display first five observations using head()
df_prod.head()
# Out:
#           Products  Prod_id    Cust_id      Sales  Order_Quan   Profit  \
# 0  COPIERS AND FAX  Prod_16  Cust_1088  10909.641          40  2616.46
# 1  COPIERS AND FAX  Prod_16  Cust_1820  10607.641          27  2977.36
# 2            PAPER   Prod_6  Cust_1659    754.641          13    29.80
# 3            PAPER   Prod_6   Cust_622    572.641          22    92.78
# 4  OFFICE MACHINES  Prod_17   Cust_564  10128.641          50  5133.68
#
#    Shipping_Cost  Product_Base_Margin Customer_Segment
# 0          22.00                 0.57      HOME OFFICE
# 1          23.69                 0.56        CORPORATE
# 2           8.90                 0.37   SMALL BUSINESS
# 3          10.99                 0.39   SMALL BUSINESS
# 4          20.50                 0.36   SMALL BUSINESS

# %% [markdown]
# ### 4a.i)Provide a summary statistics of all the variables, with respect to sales which variables have high correlation (more than .55), moderate (.4-.55) and low correlation. - 3marks

# %% [markdown]
# ### 4a.ii)Provide a histogram for the variable sales and profit, based on histogram and cacluation of skewness and kurtosis what would you describe about sales and profit. 4 marks

# %% [markdown]
# ### 4a.iii) Plot the plot the histogram for variable sales, profit based on customer segements,  based on these plots which segment provides more sales, profit and less sales, profit (assume bins  = 15) 4 marks

# %% [markdown]
# ### 4a.iv) Draw a scatter plot for all of the variables, what is your observation and conclusion for the relationship between sales and  the other numeric variables 4 marks

# %% [markdown]
# ### 4b. Consider the purchases.csv file and answer the following questions

# %% [markdown]
# ### 4b.i)Draw a boxplot for sales based on customer segments, what do you observe in terms of outliers, and sales difference for various segments. 3

# %% [markdown]
# ### 4b.ii)Conduct a hypothesis to see whether there is a difference in terms of sales for customer segment of home business and corporate. What do you conclude 4 - marks

# %% [markdown]
# ### 4b.iii)Conduct an hypothesis to prove whether the sales from small business segment is mote than corporate, do you agree or not. 4 marks
