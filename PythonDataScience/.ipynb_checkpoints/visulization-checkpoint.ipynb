# %% [markdown]
# Visulization using Matplotlib and Seaborn

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

df1 = pd.read_csv('lds_files_v1/lds41.csv')

# %% [markdown]
# # line plot

# %%
x1 = np.arange(1,6)
y1 = x1 * 2
y2 = x1 ** 2
print(x1)
print(y1)
print(y2)
# Out:
# [1 2 3 4 5]
# [ 2  4  6  8 10]
# [ 1  4  9 16 25]

# %%
plt.plot(x1,y1, marker='*')
plt.plot(x1,y1, marker='D', color='red', label='expo')
